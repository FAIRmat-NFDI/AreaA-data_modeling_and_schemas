# %%
import re
import pandas as pd
import numpy as np

# %%
SECTION_REPLACEMENTS = {
    "Sample parameters": "entry/sample",
    "Measurements": "entry/measurement"
}

MEASUREMENT_REPLACEMENTS = {
    "IV Curve Measurement": "iv_curve",
    "Variable Field Measurement": "variable_field"
}

MEASUREMENT_KEYS = ['Contact Sets']

def is_section(expr):
    return bool(re.search(r'^\[.+\]$', expr))

def is_measurement(expr):
    return bool(re.search(r'^\<.+\>$', expr))

def is_key(expr):
    return bool(re.search(r'^.+\s*[:|=]\s*.+$', expr))

def is_meas_header(expr):
    return bool(re.search(r'^[^\]]+\[[^\]]+\]', expr))

def get_unique_dkey(dic, dkey):
    suffix = 0
    while f'{dkey}{suffix}' in dic:
        suffix += 1
    
    return f'{dkey}{suffix}'

def split_add_key(fobj, dic, prefix, expr):
    key, *val = re.split('\s*[:|=]\s*', expr)
    jval = ''.join(val).strip()
    
    if key in MEASUREMENT_KEYS:
        data = []
        for line in fobj:
            if not line.strip():
                break
            if is_key(line):
                split_add_key(None,# There should be no deeper measurement, prevent further consum of lines 
                              dic, 
                              f'{prefix}/{key}/{jval}',
                              line)
            else:
                data.append(list(map(lambda x: x.strip(), re.split('\t+', line))))
        
        dkey = get_unique_dkey(dic,
                               f"{prefix}/{key}/{jval}/data")
        dic[dkey] = pd.DataFrame(
            np.array(data[1:], dtype=np.float64), columns=data[0]
        )
    else:
        dic[f'{prefix}/{key}'] = jval
        

def read_template_from_file(fname, encoding="iso-8859-1"):
    template = {}
    current_section = '/entry'
    current_measurement = ''
    with open(fname, encoding=encoding) as f:
        for line in f:
            if is_section(line):
                sline = line.strip()[1:-1]
                current_section = f'/{SECTION_REPLACEMENTS.get(sline, sline)}'
                current_measurement = ''
            elif is_measurement(line):
                step, _, *meas = line.partition(":")
                sline = f'{step[6:]}_' + ''.join(meas).strip()[:-1]
                current_measurement = f'/{MEASUREMENT_REPLACEMENTS.get(sline, sline)}'
            elif is_key(line):
                split_add_key(f, template,
                              f'{current_section}{current_measurement}',
                              line)
            elif is_meas_header(line):
                data = []
                for mline in f:
                    if not mline.strip():
                        break
                    data.append(list(map(lambda x: x.strip(), re.split('\t+', mline))))

                header = list(map(lambda x: x.strip(), re.split('\t+', line)))
                dkey = get_unique_dkey(template,
                                       f'{current_section}{current_measurement}/data')
                template[dkey] = \
                    pd.DataFrame(np.array(data, dtype=np.float64),
                                 columns=header)
                
    return template
            
read_template_from_file('22-127-G_Hall-RT_TT-Halter.txt')
read_template_from_file('22-127-G_20K-320K_TT-Halter_WDH_060722.txt')
# Out:
# /entry/measurement/2_Variable Field Measurement/data0
# /entry/measurement/1_Variable Temperature Measurement/data0
# /entry/measurement/1_Variable Temperature Measurement/data1
# /entry/measurement/2_Variable Temperature Measurement/data0
# /entry/measurement/2_Variable Temperature Measurement/data1
# /entry/measurement/3_Variable Temperature Measurement/data0
# /entry/measurement/3_Variable Temperature Measurement/data1
# /entry/measurement/4_Variable Temperature Measurement/data0
# /entry/measurement/4_Variable Temperature Measurement/data1
# /entry/measurement/5_Variable Temperature Measurement/data0
# /entry/measurement/5_Variable Temperature Measurement/data1
# /entry/measurement/6_Variable Temperature Measurement/data0
# /entry/measurement/6_Variable Temperature Measurement/data1
# {'/entry/sample/Sample Type': 'van der Pauw',
#  '/entry/sample/Hall Factor': '1.0',
#  '/entry/sample/Thickness': '1.8 [µm]',
#  '/entry/sample/L': '15.0 [mm]',
#  '/entry/sample/Depletion Layer Correction': 'Off',
#  '/entry/measurement/1_Variable Temperature Measurement/Start Time': '07/06/22 151551',
#  '/entry/measurement/1_Variable Temperature Measurement/Time Completed': '07/06/22 160752',
#  '/entry/measurement/1_Variable Temperature Measurement/Elapsed Time': '0521',
#  '/entry/measurement/1_Variable Temperature Measurement/Starting Temperature': '20.0 [K]',
#  '/entry/measurement/1_Variable Temperature Measurement/Ending Temperature': '28.0 [K]',
#  '/entry/measurement/1_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/1_Variable Temperature Measurement/Temperature Step': '2.0 [K]',
#  '/entry/measurement/1_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/1_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/1_Variable Temperature Measurement/Excitation Current': '1.0 [nA]',
#  '/entry/measurement/1_Variable Temperature Measurement/Resistance Range': 'High',
#  '/entry/measurement/1_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/1_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/1_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/1_Variable Temperature Measurement/data0':    Temperature [K]  Field [G]  Zero-field Resistivity [ohm cm]
#  0           20.786    -0.0450                          10047.0
#  1           21.611     0.0700                           8955.8
#  2           23.690    -0.0025                           6583.5
#  3           25.939    -0.1425                           4687.8
#  4           28.155    -0.0350                           3384.4,
#  '/entry/measurement/1_Variable Temperature Measurement/data1':    Temperature [K]  Field [G]  Resistivity [ohm cm]  Hall Coefficient [cm³/C]  \
#  0           20.741     3000.0               10250.0                 -472890.0
#  1           22.040     2999.7                8404.2                  -94955.0
#  2           24.043     3000.1                6207.3                 -236850.0
#  3           26.301     3000.2                4447.0                 -163060.0
#  4           28.627     3000.1                3068.5                 -552560.0
#
#     Carrier Density [1/cm³]  Hall Mobility [cm²/(VS)]
#  0            -1.320000e+13                   -47.070
#  1            -6.573900e+13                   -10.603
#  2            -2.635500e+13                   -35.976
#  3            -3.828200e+13                   -34.783
#  4            -1.129700e+13                  -163.270  ,
#  '/entry/measurement/2_Variable Temperature Measurement/Start Time': '07/06/22 160753',
#  '/entry/measurement/2_Variable Temperature Measurement/Time Completed': '07/06/22 163057',
#  '/entry/measurement/2_Variable Temperature Measurement/Elapsed Time': '0234',
#  '/entry/measurement/2_Variable Temperature Measurement/Starting Temperature': '30.0 [K]',
#  '/entry/measurement/2_Variable Temperature Measurement/Ending Temperature': '32.0 [K]',
#  '/entry/measurement/2_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/2_Variable Temperature Measurement/Temperature Step': '2.0 [K]',
#  '/entry/measurement/2_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/2_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/2_Variable Temperature Measurement/Excitation Current': '2.0 [nA]',
#  '/entry/measurement/2_Variable Temperature Measurement/Resistance Range': 'High',
#  '/entry/measurement/2_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/2_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/2_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/2_Variable Temperature Measurement/data0':    Temperature [K]  Field [G]  Zero-field Resistivity [ohm cm]
#  0           30.079   -0.11375                           2401.0
#  1           32.219   -0.14250                           1565.7,
#  '/entry/measurement/2_Variable Temperature Measurement/data1':    Temperature [K]  Field [G]  Resistivity [ohm cm]  Hall Coefficient [cm³/C]  \
#  0           30.712     3000.1                2105.6                 -610420.0
#  1           32.784     3000.4                1358.2                 -488640.0
#
#     Carrier Density [1/cm³]  Hall Mobility [cm²/(VS)]
#  0            -1.022600e+13                   -254.23
#  1            -1.277500e+13                   -312.09  ,
#  '/entry/measurement/3_Variable Temperature Measurement/Start Time': '07/06/22 163057',
#  '/entry/measurement/3_Variable Temperature Measurement/Time Completed': '07/06/22 170059',
#  '/entry/measurement/3_Variable Temperature Measurement/Elapsed Time': '0302',
#  '/entry/measurement/3_Variable Temperature Measurement/Starting Temperature': '35.0 [K]',
#  '/entry/measurement/3_Variable Temperature Measurement/Ending Temperature': '41.0 [K]',
#  '/entry/measurement/3_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/3_Variable Temperature Measurement/Temperature Step': '3.0 [K]',
#  '/entry/measurement/3_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/3_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/3_Variable Temperature Measurement/Excitation Current': '6.0 [nA]',
#  '/entry/measurement/3_Variable Temperature Measurement/Resistance Range': 'High',
#  '/entry/measurement/3_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/3_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/3_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/3_Variable Temperature Measurement/data0':    Temperature [K]  Field [G]  Zero-field Resistivity [ohm cm]
#  0           34.959     0.1075                           844.61
#  1           37.852    -0.0600                           421.13
#  2           40.543     0.1800                           222.53,
#  '/entry/measurement/3_Variable Temperature Measurement/data1':    Temperature [K]  Field [G]  Resistivity [ohm cm]  Hall Coefficient [cm³/C]  \
#  0           35.749     2999.8                690.53                 -407110.0
#  1           38.570     2999.9                347.82                 -294490.0
#  2           41.475     2999.8                175.61                 -172080.0
#
#     Carrier Density [1/cm³]  Hall Mobility [cm²/(VS)]
#  0            -1.533300e+13                   -482.01
#  1            -2.119700e+13                   -699.28
#  2            -3.627600e+13                   -773.28  ,
#  '/entry/measurement/4_Variable Temperature Measurement/Start Time': '07/06/22 170100',
#  '/entry/measurement/4_Variable Temperature Measurement/Time Completed': '07/06/22 173206',
#  '/entry/measurement/4_Variable Temperature Measurement/Elapsed Time': '0316',
#  '/entry/measurement/4_Variable Temperature Measurement/Starting Temperature': '45.0 [K]',
#  '/entry/measurement/4_Variable Temperature Measurement/Ending Temperature': '55.0 [K]',
#  '/entry/measurement/4_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/4_Variable Temperature Measurement/Temperature Step': '5.0 [K]',
#  '/entry/measurement/4_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/4_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/4_Variable Temperature Measurement/Excitation Current': '50.0 [nA]',
#  '/entry/measurement/4_Variable Temperature Measurement/Resistance Range': 'High',
#  '/entry/measurement/4_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/4_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/4_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/4_Variable Temperature Measurement/data0':    Temperature [K]     Field [G]  Zero-field Resistivity [ohm cm]
#  0           44.443 -2.500000e-03                           93.317
#  1           49.414 -5.500000e-02                           35.101
#  2           54.367 -8.470300e-18                           15.362,
#  '/entry/measurement/4_Variable Temperature Measurement/data1':    Temperature [K]  Field [G]  Resistivity [ohm cm]  Hall Coefficient [cm³/C]  \
#  0           45.395     3000.0                75.012                  -82393.0
#  1           50.276     3000.0                29.651                  -35299.0
#  2           55.161     3000.0                13.489                  -16693.0
#
#     Carrier Density [1/cm³]  Hall Mobility [cm²/(VS)]
#  0            -7.576100e+13                   -882.94
#  1            -1.768400e+14                  -1005.70
#  2            -3.739400e+14                  -1086.70  ,
#  '/entry/measurement/5_Variable Temperature Measurement/Start Time': '07/06/22 173206',
#  '/entry/measurement/5_Variable Temperature Measurement/Time Completed': '07/06/22 184824',
#  '/entry/measurement/5_Variable Temperature Measurement/Elapsed Time': '11618',
#  '/entry/measurement/5_Variable Temperature Measurement/Starting Temperature': '60.0 [K]',
#  '/entry/measurement/5_Variable Temperature Measurement/Ending Temperature': '80.0 [K]',
#  '/entry/measurement/5_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/5_Variable Temperature Measurement/Temperature Step': '5.0 [K]',
#  '/entry/measurement/5_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/5_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/5_Variable Temperature Measurement/Excitation Current': '1.0 [µA]',
#  '/entry/measurement/5_Variable Temperature Measurement/Resistance Range': 'Low',
#  '/entry/measurement/5_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/5_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/5_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/5_Variable Temperature Measurement/data0':    Temperature [K]  Field [G]  Zero-field Resistivity [ohm cm]
#  0           59.252    0.00375                           7.7305
#  1           64.535   -0.29000                           4.1074
#  2           69.655    0.14250                           2.5168
#  3           74.464    0.11000                           1.7207
#  4           79.194    0.03000                           1.2613,
#  '/entry/measurement/5_Variable Temperature Measurement/data1':    Temperature [K]  Field [G]  Resistivity [ohm cm]  Hall Coefficient [cm³/C]  \
#  0           59.958     2999.9                6.9608                   -9034.0
#  1           64.996     3000.0                3.9989                   -4716.2
#  2           70.662     3000.3                2.2969                   -2971.1
#  3           75.418     3000.1                1.5990                   -2058.7
#  4           79.382     3000.2                1.2512                   -1567.6
#
#     Carrier Density [1/cm³]  Hall Mobility [cm²/(VS)]
#  0            -6.909700e+14                   -1168.6
#  1            -1.323600e+15                   -1148.2
#  2            -2.101000e+15                   -1180.5
#  3            -3.032100e+15                   -1196.5
#  4            -3.981900e+15                   -1242.9  ,
#  '/entry/measurement/6_Variable Temperature Measurement/Start Time': '07/06/22 184825',
#  '/entry/measurement/6_Variable Temperature Measurement/Skipped at': '07/07/22 034411',
#  '/entry/measurement/6_Variable Temperature Measurement/Elapsed Time': '85546',
#  '/entry/measurement/6_Variable Temperature Measurement/Starting Temperature': '85.0 [K]',
#  '/entry/measurement/6_Variable Temperature Measurement/Ending Temperature': '320.0 [K]',
#  '/entry/measurement/6_Variable Temperature Measurement/Spacing': 'Linear Spacing',
#  '/entry/measurement/6_Variable Temperature Measurement/Temperature Step': '5.0 [K]',
#  '/entry/measurement/6_Variable Temperature Measurement/Field at': '3.0 [kG]',
#  '/entry/measurement/6_Variable Temperature Measurement/Measurement Type': 'Hall and Resistivity Measurement',
#  '/entry/measurement/6_Variable Temperature Measurement/Excitation Current': '10.0 [µA]',
#  '/entry/measurement/6_Variable Temperature Measurement/Resistance Range': 'Low',
#  '/entry/measurement/6_Variable Temperature Measurement/Dwell Time': '2.0 [Sec]',
#  '/entry/measurement/6_Variable Temperature Measurement/Current Reversal': 'On',
#  '/entry/measurement/6_Variable Temperature Measurement/Geometry selection': 'A and B',
#  '/entry/measurement/6_Variable Temperature Measurement/data0':     Temperature [K]  Field [G]  Zero-field Resistivity [ohm cm]
#  0            84.381   0.023750                     9.496500e-01
#  1            90.005  -0.117500                     7.487200e-01
#  2            95.957  -0.151250                     6.127000e-01
#  3            99.856   0.088750                     5.532900e-01
#  4           105.008   0.032500                     4.928300e-01
#  5           109.753  -0.170000                     4.529600e-01
#  6           114.675   0.188750                     4.227600e-01
#  7           119.682   0.042500                     4.006500e-01
#  8           124.701   0.147500                     3.846600e-01
#  9           129.733  -0.143750                     3.737300e-01
#  10          134.762   0.010000                     3.668600e-01
#  11          139.772   0.046250                     3.629400e-01
#  12          144.753   0.007500                     3.615600e-01
#  13          149.801  -0.065000                     3.622900e-01
#  14          154.769   0.125000                     3.648100e-01
#  15          159.785   0.201250                     3.689100e-01
#  16          164.784  -0.027500                     3.743200e-01
#  17          169.796   0.042500                     3.809800e-01
#  18          174.793  -0.002500                     3.887200e-01
#  19          179.794  -0.136250                     3.974400e-01
#  20          184.805   0.296250                     4.071200e-01
#  21          189.833  -0.057500                     4.177300e-01
#  22          194.821   0.108750                     4.291900e-01
#  23          199.850   0.076250                     4.416700e-01
#  24          204.854  -0.035000                     4.551300e-01
#  25          209.812  -0.132500                     4.695600e-01
#  26          214.818   0.026250                     4.848800e-01
#  27          219.727   0.068750                     4.997300e-01
#  28          224.758   0.223750                     5.127000e-01
#  29          229.764   0.001250                     5.225300e-01
#  30          234.730   0.007500                     5.321800e-01
#  31          239.691   0.041250                     5.439900e-01
#  32          244.633  -0.135000                     5.570700e-01
#  33          249.605   0.004125                     5.710200e-01
#  34          254.582  -0.037500                     5.855300e-01
#  35          259.539   0.183750                     6.005600e-01
#  36          264.528   0.117500                     6.160400e-01
#  37          269.453   0.017500                     6.317400e-01
#  38          274.470   0.007500                     6.480700e-01
#  39          279.536   0.017500                     6.646800e-01
#  40          284.469  -0.017500                     6.811100e-01
#  41          289.476   0.049750                     6.980000e-01
#  42          294.484   0.012500                     7.152200e-01
#  43          299.534  -0.033750                     7.324000e-01
#  44          304.472  -0.222500                     7.497700e-01
#  45          309.466  -0.082500                     7.671500e-01
#  46          314.612   0.106250                     7.845600e-01
#  47          200.506  -0.081250                    1.000000e+101,
#  '/entry/measurement/6_Variable Temperature Measurement/data1':     Temperature [K]  Field [G]  Resistivity [ohm cm]  \
#  0            85.918     3000.1          8.764300e-01
#  1            90.348     3000.0          7.388400e-01
#  2            95.684     3000.1          6.173600e-01
#  3           101.546     3000.1          5.284200e-01
#  4           106.243     2999.8          4.794900e-01
#  5           111.115     3000.2          4.423100e-01
#  6           116.083     3000.0          4.148900e-01
#  7           121.041     2999.9          3.950900e-01
#  8           126.079     3000.1          3.809400e-01
#  9           131.093     3000.0          3.713900e-01
#  10          136.115     3000.1          3.653400e-01
#  11          141.158     2999.8          3.622600e-01
#  12          146.162     3000.2          3.615900e-01
#  13          151.169     3000.1          3.629300e-01
#  14          156.147     3000.3          3.659600e-01
#  15          161.149     2999.9          3.704900e-01
#  16          166.142     3000.0          3.762900e-01
#  17          171.166     2999.9          3.833200e-01
#  18          176.184     3000.0          3.913900e-01
#  19          181.181     2999.9          4.004500e-01
#  20          186.176     3000.2          4.103900e-01
#  21          191.188     3000.2          4.212500e-01
#  22          196.197     3000.1          4.330100e-01
#  23          201.197     2999.9          4.457700e-01
#  24          206.187     2999.9          4.595100e-01
#  25          211.180     3000.0          4.743000e-01
#  26          216.184     3000.2          4.897300e-01
#  27          221.117     2999.9          5.041900e-01
#  28          226.130     3000.0          5.161300e-01
#  29          231.117     2999.9          5.254500e-01
#  30          236.090     3000.1          5.357100e-01
#  31          241.070     3000.0          5.480500e-01
#  32          246.014     3000.0          5.614700e-01
#  33          250.994     2999.8          5.756700e-01
#  34          255.939     2999.8          5.903200e-01
#  35          260.929     2999.9          6.055900e-01
#  36          265.909     3000.1          6.211400e-01
#  37          270.815     3000.1          6.369700e-01
#  38          275.905     2999.6          6.535400e-01
#  39          280.872     3000.1          6.699300e-01
#  40          285.858     3000.0          6.866300e-01
#  41          290.820     3000.1          7.034900e-01
#  42          295.907     3000.0          7.207900e-01
#  43          300.829     3000.2          7.379000e-01
#  44          305.822     3000.1          7.554700e-01
#  45          310.810     3000.2          7.728100e-01
#  46          316.028     3000.1          7.898100e-01
#  47            0.000        0.0         1.000000e+101
#
#      Hall Coefficient [cm³/C]  Carrier Density [1/cm³]  \
#  0                   -1096.30            -5.693800e+15
#  1                    -870.05            -7.174500e+15
#  2                    -699.43            -8.924700e+15
#  3                    -573.81            -1.087900e+16
#  4                    -497.32            -1.255200e+16
#  5                    -435.76            -1.432500e+16
#  6                    -387.06            -1.612700e+16
#  7                    -348.34            -1.792000e+16
#  8                    -316.24            -1.973900e+16
#  9                    -289.94            -2.152900e+16
#  10                   -268.73            -2.322800e+16
#  11                   -251.00            -2.487000e+16
#  12                   -235.35            -2.652400e+16
#  13                   -222.57            -2.804600e+16
#  14                   -211.26            -2.954700e+16
#  15                   -201.31            -3.100800e+16
#  16                   -192.78            -3.237900e+16
#  17                   -185.16            -3.371300e+16
#  18                   -178.39            -3.499200e+16
#  19                   -172.30            -3.622900e+16
#  20                   -167.21            -3.733100e+16
#  21                   -162.19            -3.848600e+16
#  22                   -157.81            -3.955600e+16
#  23                   -153.96            -4.054300e+16
#  24                   -150.61            -4.144500e+16
#  25                   -147.51            -4.231700e+16
#  26                   -144.75            -4.312300e+16
#  27                   -141.86            -4.400400e+16
#  28                   -138.17            -4.517900e+16
#  29                   -134.20            -4.651500e+16
#  30                   -130.22            -4.793600e+16
#  31                   -127.27            -4.904600e+16
#  32                   -124.66            -5.007200e+16
#  33                   -122.31            -5.103400e+16
#  34                   -120.05            -5.199900e+16
#  35                   -117.89            -5.294900e+16
#  36                   -115.85            -5.388000e+16
#  37                   -114.10            -5.470700e+16
#  38                   -112.34            -5.556600e+16
#  39                   -110.78            -5.634900e+16
#  40                   -109.12            -5.720300e+16
#  41                   -107.73            -5.794300e+16
#  42                   -106.33            -5.870400e+16
#  43                   -105.03            -5.943200e+16
#  44                   -103.65            -6.022300e+16
#  45                   -102.33            -6.100300e+16
#  46                   -101.39            -6.156300e+16
#  47                      0.00             0.000000e+00
#
#      Hall Mobility [cm²/(VS)]
#  0              -1.154400e+03
#  1              -1.162100e+03
#  2              -1.141600e+03
#  3              -1.037100e+03
#  4              -1.009100e+03
#  5              -9.620300e+02
#  6              -9.155500e+02
#  7              -8.694600e+02
#  8              -8.221300e+02
#  9              -7.758000e+02
#  10             -7.325300e+02
#  11             -6.915600e+02
#  12             -6.509100e+02
#  13             -6.143300e+02
#  14             -5.791000e+02
#  15             -5.456900e+02
#  16             -5.150300e+02
#  17             -4.860000e+02
#  18             -4.589100e+02
#  19             -4.335200e+02
#  20             -4.107100e+02
#  21             -3.882800e+02
#  22             -3.676900e+02
#  23             -3.486000e+02
#  24             -3.309200e+02
#  25             -3.141500e+02
#  26             -2.985400e+02
#  27             -2.838600e+02
#  28             -2.694900e+02
#  29             -2.568300e+02
#  30             -2.446900e+02
#  31             -2.339600e+02
#  32             -2.237900e+02
#  33             -2.142000e+02
#  34             -2.050200e+02
#  35             -1.963000e+02
#  36             -1.880600e+02
#  37             -1.806200e+02
#  38             -1.733400e+02
#  39             -1.666600e+02
#  40             -1.602100e+02
#  41             -1.543400e+02
#  42             -1.486700e+02
#  43             -1.434100e+02
#  44             -1.382400e+02
#  45             -1.333800e+02
#  46             -1.292400e+02
#  47             1.000000e+103  ,
#  '/entry/measurement/7_Go to Temperature 300.0 [K]/Start Time': '',
#  '/entry/measurement/7_Go to Temperature 300.0 [K]/Time Completed': '',
#  '/entry/measurement/7_Go to Temperature 300.0 [K]/Elapsed Time': '000'}
